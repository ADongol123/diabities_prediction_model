# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset= pd.read_csv("../datasets/diabetes.csv")
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# shape of the dataset
rows_shape = dataset.shape[0]
columns_shape = dataset.shape[1]
print(f"The number of rows: {rows_shape} | number of columns: {columns_shape}")
# Out:
# The number of rows: 768 | number of columns: 9

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
bloodpressure = dataset[dataset["BloodPressure"] > 100]
bloodpressure
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 43             9      171            110             24      240  45.4
# 84             5      137            108              0        0  48.8
# 106            1       96            122              0        0  22.4
# 177            0      129            110             46      130  67.1
# 207            5      162            104              0        0  37.7
# 362            5      103            108             37        0  39.2
# 369            1      133            102             28      140  32.8
# 440            0      189            104             25        0  34.3
# 549            4      189            110             31        0  28.5
# 658           11      127            106              0        0  39.0
# 662            8      167            106             46      231  37.6
# 672           10       68            106             23       49  35.5
# 691           13      158            114              0        0  42.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 43                      0.721   54        1
# 84                      0.227   37        1
# 106                     0.207   27        0
# 177                     0.319   26        1
# 207                     0.151   52        1
# 362                     0.305   65        0
# 369                     0.234   45        1
# 440                     0.435   41        1
# 549                     0.680   37        0
# 658                     0.190   51        0
# 662                     0.165   43        1
# 672                     0.285   47        0
# 691                     0.257   44        1

# %%
sns.histplot(bloodpressure,x='BloodPressure')
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Count'>

# %%
dataset_describe = dataset.describe().transpose()

# %%
dataset_describe
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
# Here we are checking the NAN or null or missing values in the dataset
dataset.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Then we check the dublicates in the dataset
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %% [markdown]
# # Analysing the data

# %% [markdown]
# ## Comparing the Pregnancies

# %%
# First cheking the number of pregnant girls with diabities and number of non pregnannt girl with diabities

grouped_data_pregnancy= dataset.groupby(['Outcome','Pregnancies'])['Pregnancies'].count()
# Here outcome 0 means that the women is note pregnaant nad 1 means she is pregnant
# dataset[dataset['Pregnancies'] == 1]['Pregnancies']
grouped_data_pregnancy

pivot_table_pregnancies = pd.pivot_table(data=dataset,values='Pregnancies',index='Outcome',aggfunc='mean')
pivot_table_pregnancies
# Out:
#          Pregnancies
# Outcome
# 0           3.298000
# 1           4.865672

# %%
import matplotlib.pyplot as plt

outcome_0 = dataset[dataset["Outcome"] == 0]["Pregnancies"]
outcome_1 = dataset[dataset["Outcome"] == 1]["Pregnancies"]

fig , axes = plt.subplots(1,2,figsize=(12,6),sharey=True)

# Outcome zero
axes[0].hist(outcome_0,bins=range(int(dataset['Pregnancies'].max()) + 1),color='green',edgecolor='white')
axes[0].set_title('Outcome 0 with (Non-diabetic)')
axes[0].set_xlabel('Number of pregnancies')
axes[0].set_ylabel('Frequency')

# Outcome one
axes[1].hist(outcome_1,bins=range(int(dataset['Pregnancies'].max()) + 1), color="red",edgecolor="white")
axes[1].set_title('Outcome 1 (Diabetic)')
axes[1].set_xlabel('Number of pregnancies')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparing Glucose Level

# %%
min_glucose_level = dataset['Glucose'].min()
max_glucose_level = dataset['Glucose'].max()

print(f"The minumum glucose level is : {min_glucose_level}")
print(f"The maximum glucose level is : {max_glucose_level}")
# Out:
# The minumum glucose level is : 0
# The maximum glucose level is : 199

# %%
# This shows the average glucose level of the person who has diabetites and the person who does not have diabities
pivot_glucose = pd.pivot_table(dataset,values='Glucose',index='Outcome',aggfunc='mean')
pivot_glucose
# Out:
#             Glucose
# Outcome
# 0        109.980000
# 1        141.257463

# %%
# Histogram of glucose level
glucose_outcome_zero = dataset[dataset['Outcome'] == 0]['Glucose']
glucose_outcome_one = dataset[dataset['Outcome'] == 1]['Glucose']

glucose_outcome_zero,glucose_outcome_one
# Out:
# (1       85
#  3       89
#  5      116
#  7      115
#  10     110
#        ...
#  762     89
#  763    101
#  764    122
#  765    121
#  767     93
#  Name: Glucose, Length: 500, dtype: int64,
#  0      148
#  2      183
#  4      137
#  6       78
#  8      197
#        ...
#  755    128
#  757    123
#  759    190
#  761    170
#  766    126
#  Name: Glucose, Length: 268, dtype: int64)

# %%
import matplotlib.pyplot as plt

glucose_outcome_0 = dataset[dataset["Outcome"] == 0]["Glucose"]
glucose_outcome_1 = dataset[dataset["Outcome"] == 1]["Glucose"]

fig , axes = plt.subplots(1,2,figsize=(12,6),sharey=True)

# Outcome zero
axes[0].hist(glucose_outcome_0,bins=range(int(dataset['Glucose'].max()) + 1),color='green',edgecolor='white')
axes[0].set_title('Glucose level Outcome 0 with (Non-diabetic)')
axes[0].set_xlabel('People Glucose level')
axes[0].set_ylabel('Frequency')

# Outcome one
axes[1].hist(glucose_outcome_1,bins=range(int(dataset['Glucose'].max()) + 1), color="red",edgecolor="white")
axes[1].set_title('Glucose level Outcome 1 (Diabetic)')
axes[1].set_xlabel('People Glucose level')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

fig , axes = plt.subplots(1,2,figsize=(12,6),sharey=True)

axes[0].boxplot(glucose_outcome_0, patch_artist=True, boxprops=dict(facecolor='green', color='white'))
axes[0].set_title('Glucose level Outcome 0 with (Non-diabetic)')
axes[0].set_xlabel('People Glucose level')
axes[0].set_ylabel('Frequency')



axes[1].boxplot(glucose_outcome_1, patch_artist=True, boxprops=dict(facecolor='red', color='white'))
axes[1].set_title('Glucose level Outcome 1 (Diabetic)')
axes[1].set_xlabel('Outcome 1 (Diabetic)')
axes[1].set_ylabel('Glucose Level')

plt.show()

# %%
# Showing in Kernel Density Plot

plt.figure(figsize=(10,7))

sns.kdeplot(data=dataset,x="Glucose",hue="Outcome",fill=True,alpha=0.5,palette={1:'green',0:'red'})
plt.title('Kernel Density Plot of the glucose by target Status')
plt.grid()
plt.show()

# %% [markdown]
# ### Outcomes
# * The Non-Diabetic group (Outcome 0) has a strong peak around 100 mg/dL of glucose, indicating that most non-diabetic individuals have glucose levels centered around this value.
# * The Diabetic group (Outcome 1) shows a broader distribution with a peak around 150 mg/dL, and the values spread further toward higher glucose levels (even going beyond 200 mg/dL).
# * There's a clear separation between the distributions of glucose levels for the two outcomes. This separation suggests that glucose levels are a strong distinguishing factor between diabetic and non-diabetic   individuals.
# *  The diabetic group has a larger proportion of individuals with higher glucose levels, while the non-diabetic group is more concentrated around lower glucose values.
# * `Glucose level` is a highly important feature in distinguishing between diabetic and non-diabetic individuals. Higher glucose levels are strongly associated with diabetes.
# * The separation between the two distributions indicates that glucose might be a more powerful predictor for diabetes compared to blood pressure (based on the previous KDE plot you provided).

# %% [markdown]
# ## Comparing the Blood pressure

# %%
min_blood_pressure = dataset['BloodPressure'].min()
max_blood_pressure = dataset['BloodPressure'].max()

print(f"The minumum blood pressure is : {min_blood_pressure}")
print(f"The maximum blood pressure is : {max_blood_pressure}")
# Out:
# The minumum blood pressure is : 0
# The maximum blood pressure is : 122

# %%
# Creating a pivot table of the Blood pressure
blood_pressure_pivot_table = pd.pivot_table(dataset,values="BloodPressure",index="Outcome",aggfunc='mean')
blood_pressure_pivot_table
# Out:
#          BloodPressure
# Outcome
# 0            68.184000
# 1            70.824627

# %%
import matplotlib.pyplot as plt


blood_pressure_outcome0 = dataset[dataset['Outcome'] == 0 ]['BloodPressure']
blood_pressure_outcome1 = dataset[dataset['Outcome'] == 1 ]['BloodPressure']

fig, axes = plt.subplots(1,2,figsize=(12,9),sharey=True)


axes[0].hist(blood_pressure_outcome0,bins=range(int(dataset['BloodPressure'].max()) + 1),color='green',edgecolor='white')
axes[0].set_title('Blood Pressure  Outcome 0 with (Non-diabetic)')
axes[0].set_xlabel('People Blood pressure level')
axes[0].set_ylabel('Frequency')

axes[1].hist(blood_pressure_outcome1,bins=range(int(dataset['BloodPressure'].max()) + 1),color='red',edgecolor='white')
axes[1].set_title('Blood Pressure  Outcome 1 with (Diabetic)')
axes[1].set_xlabel('People Blood pressure level')
axes[1].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt

fig , axes = plt.subplots(1,2,figsize=(12,6),sharey=True)

axes[0].boxplot(blood_pressure_outcome0, patch_artist=True, boxprops=dict(facecolor='green', color='white'))
axes[0].set_title('BP level Outcome 0 with (Non-diabetic)')
axes[0].set_xlabel('People Glucose level')
axes[0].set_ylabel('Frequency')



axes[1].boxplot(blood_pressure_outcome1, patch_artist=True, boxprops=dict(facecolor='red', color='white'))
axes[1].set_title('BP level Outcome 1 (Diabetic)')
axes[1].set_xlabel('Outcome 1 (Diabetic)')
axes[1].set_ylabel('Glucose Level')

plt.show()

# %%
# Showing in Kernel Density Plot

plt.figure(figsize=(10,7))

sns.kdeplot(data=dataset,x="BloodPressure",hue="Outcome",fill=True,alpha=0.5,palette={1:'green',0:'red'})
plt.title('Kernel Density Plot of the glucose by target Status')
plt.grid()
plt.show()

# %% [markdown]
# ### Outcomes
# * There's a significant overlap between the distributions of blood pressure for both outcomes. This suggests that blood pressure alone may not be a highly distinctive feature for differentiating between diabetic and non-diabetic individuals, as both groups show similar ranges.
# * The peak of the distribution for Outcome 0 (Non-Diabetic) is slightly higher compared to Outcome 1, suggesting that non-diabetic individuals have a higher concentration of blood pressure values around the 70-80 range.
# * Diabetic individuals (green) have a relatively flatter and lower peak, indicating more spread or variability in their blood pressure values.
# * Blood pressure values for both diabetic and non-diabetic individuals are centered around similar ranges, although non-diabetic individuals tend to have slightly higher densities.
# * This plot alone suggests that blood pressure may not be the best single feature for distinguishing between diabetic and non-diabetic individuals. However, in combination with other features, it might still contribute to model performance.

# %% [markdown]
# ## Comparing Skin Thickness

# %%
Max_skin_thickness = dataset['SkinThickness'].max()
Min_skin_thickness = dataset['SkinThickness'].min()

print(f"The maximum skin thickness: {Max_skin_thickness}")
print(f"The minimum skin thickness: {Min_skin_thickness}")
# Out:
# The maximum skin thickness: 99
# The minimum skin thickness: 0

# %%
pivot_table_skin_thickness = pd.pivot_table(dataset,values='SkinThickness',index='Outcome',aggfunc='mean' )
pivot_table_skin_thickness
# Out:
#          SkinThickness
# Outcome
# 0            19.664000
# 1            22.164179

# %%
import matplotlib.pyplot as plt


blood_pressure_outcome0 = dataset[dataset['Outcome'] == 0 ]['SkinThickness']
blood_pressure_outcome1 = dataset[dataset['Outcome'] == 1 ]['SkinThickness']

fig, axes = plt.subplots(1,2,figsize=(12,9),sharey=True)


axes[0].hist(blood_pressure_outcome0,bins=range(int(dataset['SkinThickness'].max()) + 1),color='green',edgecolor='white')
axes[0].set_title('SkinThickness  Outcome 0 with (Non-diabetic)')
axes[0].set_xlabel('SkinThickness pressure level')
axes[0].set_ylabel('Frequency')

axes[1].hist(blood_pressure_outcome1,bins=range(int(dataset['BloodPressure'].max()) + 1),color='red',edgecolor='white')
axes[1].set_title('SkinThickness  Outcome 1 with (Diabetic)')
axes[1].set_xlabel('People  SkinThickness level')
axes[1].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Showing in Kernel Density Plot

plt.figure(figsize=(10,7))

sns.kdeplot(data=dataset,x="SkinThickness",hue="Outcome",fill=True,alpha=0.5,palette={1:'green',0:'red'})
plt.title('Kernel Density Plot of the skin thickness by target Status')
plt.grid()
plt.show()

# %% [markdown]
# ### Outcomes
#
# * Most of the data for skin thickness seems to be concentrated between 0 - 40 mm.
# * There is a `bi-modal distribution` for Outcome 0 , while the distribution for Outcome 1 is more concentrated around 30 mm
# * Outcome 1 has a much lower density, which might indicate that in the dataset, people with highter skin thickness are less likely to have diabities.

# %% [markdown]
# ## Comparing Insulin Levels

# %%
## Comparing the Insulin Level
Max_insulin = dataset['Insulin'].max()
Min_insulin = dataset['Insulin'].min()

print(f"The maximum skin thickness: {Max_insulin}")
print(f"The minimum skin thickness: {Min_insulin}")
# Out:
# The maximum skin thickness: 846
# The minimum skin thickness: 0

# %%
pivot_table_insulin = pd.pivot_table(dataset,values='Insulin',index='Outcome',aggfunc='mean')
pivot_table_insulin
# Out:
#             Insulin
# Outcome
# 0         68.792000
# 1        100.335821

# %%
import matplotlib.pyplot as plt

insulin_outcome_0 = dataset[dataset["Outcome"] == 0]["Insulin"]
insulin_outcome_1 = dataset[dataset["Outcome"] == 1]["Insulin"]

fig , axes = plt.subplots(1,2,figsize=(12,6),sharey=True)

# Outcome zero
axes[0].hist(insulin_outcome_0,bins=50,color='green',edgecolor='white')
axes[0].set_title('Outcome 0 with (Non-diabetic)')
axes[0].set_xlabel('Number of Insulin')
axes[0].set_ylabel('Frequency')

# Outcome one
axes[1].hist(insulin_outcome_1,bins=50, color="red",edgecolor="white")
axes[1].set_title('Outcome 1 (Diabetic)')
axes[1].set_xlabel('Number of Insulin')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Showing in Kernel Density Plot

plt.figure(figsize=(10,7))

sns.kdeplot(data=dataset,x="Insulin",hue="Outcome",fill=True,alpha=0.5,palette={1:'green',0:'red'})
plt.title('Kernel Density Plot of the Insulin by target Status')
plt.grid()
plt.show()

# %% [markdown]
# ### Outcomes
#
# * Both the red and green curves have a sharp peak at very low insulin levels (close to 0). This means that the majority of individuals (both diabetic and non-diabetic) in your dataset have relatively low insulin levels.
# * The green curve for diabetic individuals has a smaller peak compared to the red curve, implying that fewer diabetic individuals have very low insulin levels. Instead, the green curve seems to have more spread toward higher insulin values, though this is subtle.
# * Both curves have a "tail" stretching to the right, representing individuals with higher insulin levels (100-600 or more). This tail suggests that while most individuals have low insulin levels, a few have much higher levels, especially among diabetic individuals.
# * The red area under the curve at low insulin levels (close to 0) is larger than the green area. This suggests that non-diabetic individuals tend to have very low insulin levels more frequently than diabetic individuals.
# * Diabetic individuals show a more spread-out distribution, with slightly fewer having very low insulin levels, and some having higher insulin levels (though both groups taper off at higher values).

# %% [markdown]
# ## Comparing the BMI (Body Mass Index)

# %%
Maximum_body_weight = dataset['BMI'].max()
Minimum_body_weight = dataset['BMI'].min()

print(f'The max BMI is : {Maximum_body_weight}')
print(f'The min BMI is : {Minimum_body_weight}')
# Out:
# The max BMI is : 67.1
# The min BMI is : 0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the histogram of BMI
plt.figure(figsize=(8, 6))
sns.histplot(data=dataset, x="BMI", kde=True, bins=30, color='blue')
plt.title('Distribution of BMI in the Diabetes Dataset')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=dataset[dataset['Outcome'] == 0]['BMI'], color='green', label='Non-diabetic', fill=True)
sns.kdeplot(data=dataset[dataset['Outcome'] == 1]['BMI'], color='red', label='Diabetic', fill=True)
plt.title('KDE Plot of BMI by Diabetes Outcome')
plt.xlabel('BMI')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(hue='Outcome', y='BMI', data=dataset, palette='Set2',legend=True)
plt.title('Box Plot of BMI by Diabetes Outcome')
plt.xlabel('Diabetes Outcome')
plt.ylabel('BMI')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=dataset, x='Age', y='BMI', hue='Outcome', palette='coolwarm')
plt.title('Scatter Plot of BMI vs Age by Diabetes Outcome')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# ![image.png](attachment:fdb70c51-bed2-4dcc-88b0-810ee8be3f55.png)![image.png](attachment:9fcea3e6-87af-4533-989c-908022805044.png)

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Define BMI categories based on WHO classification
def classify_bmi(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif 18.5 <= bmi < 24.9:
        return 'Normal weight'
    elif 25 <= bmi < 29.9:
        return 'Overweight'
    else:
        return 'Obese'

# Apply classification to the BMI column
dataset['BMI_Category'] = dataset['BMI'].apply(classify_bmi)

# Count the number of people in each BMI category
bmi_counts = dataset['BMI_Category'].value_counts()
print(bmi_counts.index)
# Plotting the counts as a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(hue=bmi_counts.index, y=bmi_counts.values, palette="Set2")
plt.title("Distribution of BMI Categories")
plt.xlabel("BMI Category")
plt.ylabel("Number of People")
plt.show()

plt.figure(figsize=(7, 7))
explode = (0.1, 0) 
plt.pie(bmi_counts.values, labels=bmi_counts.index, autopct='%1.1f%%', colors=sns.color_palette("Set2"), shadow=True, startangle=90)
plt.title("Proportion of People by BMI Category")
plt.show()
# Out:
# Index(['Obese', 'Overweight', 'Normal weight', 'Underweight'], dtype='object', name='BMI_Category')

# %% [markdown]
# ## Comparing the Diabetes Pedigree Function

# %%
DiabetesPedigreeFunction_max_value = dataset['DiabetesPedigreeFunction'].max()
DiabetesPedigreeFunction_min_value =dataset['DiabetesPedigreeFunction'].min()

print(f'The max value is : {DiabetesPedigreeFunction_max_value}')
print(f'The min value is : {DiabetesPedigreeFunction_min_value}')
# Out:
# The max value is : 2.42
# The min value is : 0.078

# %%
# pivot table

DiabetesPedigreeFunction_pivot_table = pd.pivot_table(dataset,values='DiabetesPedigreeFunction',index='Outcome',aggfunc='mean')
DiabetesPedigreeFunction_pivot_table
# Out:
#          DiabetesPedigreeFunction
# Outcome
# 0                        0.429734
# 1                        0.550500

# %%
# histogram

import matplotlib.pyplot as plt


DiabetesPedigreeFunction_Outcome_0 = dataset[dataset['Outcome'] == 0 ]['DiabetesPedigreeFunction']
DiabetesPedigreeFunction_Outcome_1 = dataset[dataset['Outcome'] == 1 ]['DiabetesPedigreeFunction']

fig, axes = plt.subplots(1,2,figsize=(12,9),sharey=True)


axes[0].hist(DiabetesPedigreeFunction_Outcome_0,bins=10,color='green',edgecolor='white')
axes[0].set_title('Blood Pressure  Outcome 0 with (Non-diabetic)')
axes[0].set_xlabel('People Blood pressure level')
axes[0].set_ylabel('Frequency')

axes[1].hist(DiabetesPedigreeFunction_Outcome_1,bins=10,color='red',edgecolor='white')
axes[1].set_title('Blood Pressure  Outcome 1 with (Diabetic)')
axes[1].set_xlabel('People Blood pressure level')
axes[1].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=dataset[dataset['Outcome'] == 0]['DiabetesPedigreeFunction'], color='green', label='Non-diabetic', fill=True)
sns.kdeplot(data=dataset[dataset['Outcome'] == 1]['DiabetesPedigreeFunction'], color='red', label='Diabetic', fill=True)
plt.title('KDE Plot of DiabetesPedigreeFunction by Diabetes Outcome')
plt.xlabel('DiabetesPedigreeFunction')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# ## Comparing the Age

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Outcome', y='Age', data=dataset)
plt.title('Box Plot of Age by Diabetes Outcome')
plt.xlabel('Diabetes Outcome (0: No, 1: Yes)')
plt.ylabel('Age')
plt.xticks([0, 1], ['No Diabetes', 'Diabetes'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=dataset, x='Age', hue='Outcome', multiple='stack', bins=30)
plt.title('Histogram of Age by Diabetes Outcome')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Diabetes Outcome', labels=['No Diabetes (0)', 'Diabetes (1)'])
plt.show()

# %% [markdown]
# ## Diabetic person vs Non-Diabetic person

# %%
# Calculate counts of diabetic and non-diabetic outcomes
outcome_counts = dataset['Outcome'].value_counts()

# Prepare data for the pie chart
labels = ['No Diabetes (0)', 'Diabetes (1)']
sizes = outcome_counts.values
colors = ['#ff9999', '#66b3ff']  # Colors for the pie chart
explode = (0.1, 0)  # explode the 1st slice (Diabetes)

# Create the pie chart
plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Diabetic vs Non-Diabetic Outcomes')
plt.show()

# %%
import requests
from pathlib import Path

# Download helper funtions from LEran PyTorch repo
if Path("helper_functions.py").is_file():
    print("helper_functions.py already exists, skipping download...")

else:
    print("Downloading helper function.py")
    request = requests.get("https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/refs/heads/main/helper_functions.py")
    with open("helper_functions.py","wb") as f:
        f.write(request.content)
# Out:
# Downloading helper function.py

# %% [markdown]
# # Creating a model

# %%
dataset= pd.read_csv("../datasets/diabetes.csv")
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from helper_functions import accuracy_fn

# %%
X=dataset.drop('Outcome',axis=1).values### independent features
y=dataset['Outcome'].values###dependent features

# %%
# data = pd.get_dummies(dataset, columns=['BMI_Category'], drop_first=True)

# %%
# X = dataset.drop('Outcome', axis=1).values  # Features
# y = dataset['Outcome'].values  # Target variable
# X,y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
len(X_test),len(X_train),len(y_train),len(y_test)
# Out:
# (154, 614, 614, 154)

# %%
dataset.shape
# Out:
# (768, 9)

# %%
X_train = torch.FloatTensor(X_train)
y_train = torch.LongTensor(y_train)
X_test = torch.FloatTensor(X_test)
y_test = torch.LongTensor(y_test)

X_test.dtype,X_train.dtype,y_train.dtype,y_test.dtype
# Out:
# (torch.float32, torch.float32, torch.int64, torch.int64)

# %%
# print(data.dtypes)  # Check data types of all columns

# %%
class Diabities_Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.first = nn.Linear(in_features=8, out_features=20)
        # self.batch_norm1 = nn.BatchNorm1d(20)
        # self.dropout1 = nn.Dropout(0.2)
        
        self.second = nn.Linear(in_features=20, out_features=20)
        # self.batch_norm2 = nn.BatchNorm1d(20)
        # self.dropout2 = nn.Dropout(0.2)
        
        self.out = nn.Linear(in_features=20, out_features=2)

    def forward(self,x):
        x=F.relu(self.first(x))
        # x = self.dropout1(x)
        
        x=F.relu(self.second(x))
        # x=self.dropout2(x)
        
        x=self.out(x)
        return x

# %%
# Creating a model
torch.manual_seed(42)
model_0 = Diabities_Model()
model_0.parameters
# Out:
# <bound method Module.parameters of Diabities_Model(
#   (first): Linear(in_features=8, out_features=20, bias=True)
#   (second): Linear(in_features=20, out_features=20, bias=True)
#   (out): Linear(in_features=20, out_features=2, bias=True)
# )>

# %%
# Creating a loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_0.parameters(),lr=0.01)

# %%
# Traning and Testing the model
y_train = y_train.long()
y_test = y_test.long()

torch.manual_seed(42)

epochs = 500

final_losses = []

for epoch in range(epochs):
    model_0.train()

    y_pred=model_0(X_train)

    loss= loss_fn(y_pred,y_train)

    acc = accuracy_fn(y_true=y_train,
                     y_pred = y_pred.argmax(dim=1))
    
    final_losses.append(loss.detach().item())
    
    optimizer.zero_grad()

    loss.backward()

    optimizer.step()

    # Testing the model

    model_0.eval()
    with torch.inference_mode():
        test_pred = model_0(X_test)
        test_loss = loss_fn(test_pred,y_test)
        test_acc = accuracy_fn(y_true=y_test,y_pred=test_pred.argmax(dim=1))
    if epoch % 10 == 0:
        print(f"The epoch is: {epoch} | loss: {test_loss} | Test Accuracy: {test_acc:.4f}% ")


test_loss
# Out:
# The epoch is: 0 | loss: 72.71990966796875 | Test Accuracy: 68.8312%
# The epoch is: 10 | loss: 2.312953233718872 | Test Accuracy: 68.8312%
# The epoch is: 20 | loss: 0.7117311358451843 | Test Accuracy: 69.4805%
# The epoch is: 30 | loss: 0.8966356515884399 | Test Accuracy: 30.5195%
# The epoch is: 40 | loss: 0.6289659738540649 | Test Accuracy: 69.4805%
# The epoch is: 50 | loss: 0.616314172744751 | Test Accuracy: 69.4805%
# The epoch is: 60 | loss: 0.6408864855766296 | Test Accuracy: 69.4805%
# The epoch is: 70 | loss: 0.6323577761650085 | Test Accuracy: 69.4805%
# The epoch is: 80 | loss: 0.6202720403671265 | Test Accuracy: 69.4805%
# The epoch is: 90 | loss: 0.6188876628875732 | Test Accuracy: 69.4805%
# The epoch is: 100 | loss: 0.6203352808952332 | Test Accuracy: 69.4805%
# The epoch is: 110 | loss: 0.621738851070404 | Test Accuracy: 69.4805%
# The epoch is: 120 | loss: 0.6223139762878418 | Test Accuracy: 69.4805%
# The epoch is: 130 | loss: 0.6223720908164978 | Test Accuracy: 69.4805%
# The epoch is: 140 | loss: 0.6222758889198303 | Test Accuracy: 69.4805%
# The epoch is: 150 | loss: 0.6221778392791748 | Test Accuracy: 69.4805%
# The epoch is: 160 | loss: 0.6221109628677368 | Test Accuracy: 69.4805%
# The epoch is: 170 | loss: 0.6220700740814209 | Test Accuracy: 69.4805%
# The epoch is: 180 | loss: 0.6220453381538391 | Test Accuracy: 69.4805%
# The epoch is: 190 | loss: 0.6220299601554871 | Test Accuracy: 69.4805%
# The epoch is: 200 | loss: 0.6220200061798096 | Test Accuracy: 69.4805%
# The epoch is: 210 | loss: 0.6220136880874634 | Test Accuracy: 69.4805%
# The epoch is: 220 | loss: 0.6220099329948425 | Test Accuracy: 69.4805%
# The epoch is: 230 | loss: 0.6220086216926575 | Test Accuracy: 69.4805%
# The epoch is: 240 | loss: 0.6220082640647888 | Test Accuracy: 69.4805%
# The epoch is: 250 | loss: 0.6220090985298157 | Test Accuracy: 69.4805%
# The epoch is: 260 | loss: 0.6220097541809082 | Test Accuracy: 69.4805%
# The epoch is: 270 | loss: 0.6220102310180664 | Test Accuracy: 69.4805%
# The epoch is: 280 | loss: 0.6220102310180664 | Test Accuracy: 69.4805%
# The epoch is: 290 | loss: 0.6220099329948425 | Test Accuracy: 69.4805%
# The epoch is: 300 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 310 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 320 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 330 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 340 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 350 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 360 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 370 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 380 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 390 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 400 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 410 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 420 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 430 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 440 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 450 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 460 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 470 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 480 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 490 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 500 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 510 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 520 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 530 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 540 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 550 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 560 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 570 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 580 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 590 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 600 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 610 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 620 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 630 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 640 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 650 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 660 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 670 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 680 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 690 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 700 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 710 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 720 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 730 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 740 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 750 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 760 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 770 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 780 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 790 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 800 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 810 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 820 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 830 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 840 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 850 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 860 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 870 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 880 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 890 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 900 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 910 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 920 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 930 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 940 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 950 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 960 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 970 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 980 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 990 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1000 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1010 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1020 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1030 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1040 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1050 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1060 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1070 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1080 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1090 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1100 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1110 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1120 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1130 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1140 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1150 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1160 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1170 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1180 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1190 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1200 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1210 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1220 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1230 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1240 | loss: 0.622009813785553 | Test Accuracy: 69.4805%
# The epoch is: 1250 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1260 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1270 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1280 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1290 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1300 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1310 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1320 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1330 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1340 | loss: 0.622009813785553 | Test Accuracy: 69.4805%
# The epoch is: 1350 | loss: 0.6220098733901978 | Test Accuracy: 69.4805%
# The epoch is: 1360 | loss: 0.6220098733901978 | Test Accuracy: 69.4805%
# The epoch is: 1370 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1380 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1390 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1400 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1410 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1420 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1430 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1440 | loss: 0.6220098733901978 | Test Accuracy: 69.4805%
# The epoch is: 1450 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1460 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1470 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1480 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1490 | loss: 0.622009813785553 | Test Accuracy: 69.4805%
# The epoch is: 1500 | loss: 0.6220099329948425 | Test Accuracy: 69.4805%
# The epoch is: 1510 | loss: 0.6220099329948425 | Test Accuracy: 69.4805%
# The epoch is: 1520 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1530 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1540 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1550 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1560 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1570 | loss: 0.6220101714134216 | Test Accuracy: 69.4805%
# The epoch is: 1580 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1590 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1600 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1610 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1620 | loss: 0.6220097541809082 | Test Accuracy: 69.4805%
# The epoch is: 1630 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1640 | loss: 0.6220101714134216 | Test Accuracy: 69.4805%
# The epoch is: 1650 | loss: 0.6220101714134216 | Test Accuracy: 69.4805%
# The epoch is: 1660 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1670 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1680 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1690 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1700 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1710 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1720 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1730 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1740 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1750 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1760 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1770 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1780 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1790 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1800 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1810 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1820 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1830 | loss: 0.622009813785553 | Test Accuracy: 69.4805%
# The epoch is: 1840 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1850 | loss: 0.6220098733901978 | Test Accuracy: 69.4805%
# The epoch is: 1860 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1870 | loss: 0.6220097541809082 | Test Accuracy: 69.4805%
# The epoch is: 1880 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1890 | loss: 0.6220099329948425 | Test Accuracy: 69.4805%
# The epoch is: 1900 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1910 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1920 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1930 | loss: 0.6220101118087769 | Test Accuracy: 69.4805%
# The epoch is: 1940 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1950 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1960 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1970 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1980 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# The epoch is: 1990 | loss: 0.6220099925994873 | Test Accuracy: 69.4805%
# tensor(0.6220)

# %%
plt.plot(range(epochs), final_losses)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
